# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyasrimandala/dav_project/blob/main/DAV_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/global air pollution dataset (1).csv')

# %%
df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
df=pd.read_csv('/content/global air pollution dataset (1).csv')

# %%
#Display first 15 rows of the dataset
df.head(15)
# Out:
#                         Country              City  AQI Value  \
# 0            Russian Federation        Praskoveya         51
# 1                        Brazil  Presidente Dutra         41
# 2                         Italy   Priolo Gargallo         66
# 3                        Poland         Przasnysz         34
# 4                        France          Punaauia         22
# 5      United States of America       Punta Gorda         54
# 6                       Germany        Puttlingen         62
# 7                       Belgium             Puurs         64
# 8            Russian Federation        Pyatigorsk         54
# 9                         Egypt            Qalyub        142
# 10                        China           Qinzhou         68
# 11                  Netherlands            Raalte         41
# 12                        India            Radaur        158
# 13                     Pakistan            Radhan        158
# ...

# %%
df=pd.read_csv('/content/global air pollution dataset (1).csv')

# %%
# Display last 15 rows of the dataset
df.tail(15)
# Out:
#                                                  Country              City  \
# 23448                                           Colombia           Viterbo
# 23449                                              China          Wangqing
# 23450                           United States of America           El Reno
# 23451                                          Sri Lanka           Wattala
# 23452                                           Pakistan          Havelian
# 23453  United Kingdom of Great Britain and Northern I...           Urmston
# 23454                                              India            Konnur
# 23455                                              China          Shaoguan
# 23456                           United States of America  Highland Springs
# 23457                                           Slovakia            Martin
# 23458                                              India      Gursahaiganj
# ...

# %%
#checking missing values
print("Any value?", df.isnull().values.any)
# Out:
# Any value? <built-in method any of numpy.ndarray object at 0x78a98b2dd3b0>

# %%
#checking missing values
print("Any value?",df.isnull().values.any)
df.isnull()
# Out:
# Any value? <built-in method any of numpy.ndarray object at 0x78a98b2cf570>
#        Country   City  AQI Value  AQI Category  CO AQI Value  CO AQI Category  \
# 0        False  False      False         False         False            False
# 1        False  False      False         False         False            False
# 2        False  False      False         False         False            False
# 3        False  False      False         False         False            False
# 4        False  False      False         False         False            False
# ...        ...    ...        ...           ...           ...              ...
# 23458    False  False      False         False         False            False
# 23459    False  False      False         False         False            False
# 23460    False  False      False         False         False            False
# 23461    False  False      False         False         False            False
# ...

# %%
# drop all missing values
df.dropna(axis=0)
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
# check for duplicate data
dup_data=df.duplicated().any()
print("Are there any duplicate values:",dup_data)
# Out:
# Are there any duplicate values: False

# %%
print("Are there any duplicate values:",dup_data)
# Out:
# Are there any duplicate values: False

# %%
# overall statistics about the dataframe
df.describe()
# Out:
#           AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# count  23463.000000  23463.000000     23463.000000   23463.000000
# mean      72.010868      1.368367        35.193709       3.063334
# std       56.055220      1.832064        28.098723       5.254108
# min        6.000000      0.000000         0.000000       0.000000
# 25%       39.000000      1.000000        21.000000       0.000000
# 50%       55.000000      1.000000        31.000000       1.000000
# 75%       79.000000      1.000000        40.000000       4.000000
# max      500.000000    133.000000       235.000000      91.000000
#
#        PM2.5 AQI Value
# count     23463.000000
# mean         68.519755
# std          54.796443
# min           0.000000
# 25%          35.000000
# 50%          54.000000
# 75%          79.000000
# max         500.000000

# %%
# highest average Value
df.columns
# Out:
# Index(['Country', 'City', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category'],
#       dtype='object')

# %%
# number of country counts
df['Country'].value_counts()
# Out:
# Country
# United States of America    2872
# India                       2488
# Brazil                      1562
# Germany                     1345
# Russian Federation          1241
#                             ...
# Vanuatu                        1
# Solomon Islands                1
# Republic of Korea              1
# Saint Lucia                    1
# Monaco                         1
# Name: count, Length: 175, dtype: int64

# %%
# finding highest value
df['AQI Category'].max
df[df['AQI Category'].max()==df['AQI Category']]
# Out:
#             Country          City  AQI Value    AQI Category  CO AQI Value  \
# 43            India     Darbhanga        247  Very Unhealthy             3
# 77            China      Hangzhou        203  Very Unhealthy             5
# 278    South Africa  Ballitoville        222  Very Unhealthy            12
# 351           India       Bhinmal        202  Very Unhealthy             0
# 429           India     Sahibganj        208  Very Unhealthy             3
# ...             ...           ...        ...             ...           ...
# 22789         India       Sonipat        216  Very Unhealthy            10
# 22837         India     Rajakhera        250  Very Unhealthy             1
# 23047         China         Homei        204  Very Unhealthy             4
# 23154         China       Xuchang        202  Very Unhealthy             4
# 23372      Pakistan  Mian Channun        252  Very Unhealthy             2
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/global air pollution dataset (2).csv')

# %%
# find shape of our dataset(Number of rows and columns)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             23036 non-null  object
#  1   City                23462 non-null  object
#  2   AQI Value           23463 non-null  int64
#  3   AQI Category        23463 non-null  object
#  4   CO AQI Value        23463 non-null  int64
#  5   CO AQI Category     23463 non-null  object
#  6   Ozone AQI Value     23463 non-null  int64
#  7   Ozone AQI Category  23463 non-null  object
#  8   NO2 AQI Value       23463 non-null  int64
#  9   NO2 AQI Category    23463 non-null  object
#  10  PM2.5 AQI Value     23463 non-null  int64
#  11  PM2.5 AQI Category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %%
# getting information about dataset like number of rows and columns,datatype of
# each column and memory requirement
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             23036 non-null  object
#  1   City                23462 non-null  object
#  2   AQI Value           23463 non-null  int64
#  3   AQI Category        23463 non-null  object
#  4   CO AQI Value        23463 non-null  int64
#  5   CO AQI Category     23463 non-null  object
#  6   Ozone AQI Value     23463 non-null  int64
#  7   Ozone AQI Category  23463 non-null  object
#  8   NO2 AQI Value       23463 non-null  int64
#  9   NO2 AQI Category    23463 non-null  object
#  10  PM2.5 AQI Value     23463 non-null  int64
#  11  PM2.5 AQI Category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %%
# display top 15 highest AQI Values
top15_len = df.sort_values(by='AQI Value', ascending=False).head(15)[['City','AQI Value']].set_index('City')
print(top15_len)
# Out:
#               AQI Value
# City
# Haldaur             500
# Mahendragarh        500
# Barkhera            500
# Khetri              500
# Jahangirpur         500
# Phalauda            500
# Patiala             500
# Kakrala             500
# Kandhla             500
# Hasanpur            500
# Dhuri               500
# Lachhmangarh        500
# Malaut              500
# Padampur            500
# Jhunjhunun          500

# %%
def City(City):
  if ValueError>=65:
    return 'Moderate'
  elif ValueError>=40:
    return 'Good'
  else:
    return 'Unhealthy'
